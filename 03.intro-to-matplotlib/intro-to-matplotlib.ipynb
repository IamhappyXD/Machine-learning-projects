# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4])

# %%
x = [2,4,6,8]
y = [4,16,36,64]
plt.plot(x,y)

# %%
#1st method
fig = plt.figure() #create figures
ax = fig.add_subplot() # add some axes
plt.show()

# %%
#2nd method
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
# 3rd method
fig, ax = plt.subplots()
ax.plot(x,[50,100,200,300]);

# %%
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %%
#matplotlib ex workflow
# import
# %matplotlib inline
import matplotlib.pyplot as plt

#data 
x = [1,2,3,5,10]
y = [ 10,19,20,30,40]

# setup plot
fig, ax = plt.subplots(figsize = (5,5))
#10,10 width height
ax.plot(x,y)
ax.set(title = "Plot", xlabel = "x-ax", ylabel="y-l")

fig.savefig("plot.png")

# %% [markdown]
# ### making fig with numpy arrays

# %%
import numpy as np

# %%
x = np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
#create line plot
fig, ax1 = plt.subplots()
ax1.plot(x, x**2);

# %%
# scatter plot
fig, ax2 = plt.subplots()
ax2.scatter(x, np.exp(x))

# %%
fig, ax3 = plt.subplots()
ax3.scatter(x, np.sin(x))

# %%
nut_price = {"Almon": 10, "Peam": 19, "Cah": 12}
fig, ax4 = plt.subplots()
ax4.bar(nut_price.keys(),height =  nut_price.values());
ax4.set(title="Butter Store",ylabel = "Price", xlabel="Types of butter" );

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_price.keys()), list(nut_price.values()));

# %%
x = np.random.randn(1000)
fix, ax = plt.subplots()
ax.hist(x);

# %%
x
# Out:
# array([-6.28696966e-01, -1.53610024e+00, -2.41646317e-01,  1.53122042e+00,
#        -1.72016848e+00, -2.59897945e-01,  5.04640885e-01, -2.48334498e+00,
#        -4.45679726e-01, -1.25023358e+00, -7.91161487e-01, -1.49130345e+00,
#        -8.50406987e-02, -1.69799914e+00,  3.40128212e-02,  5.89568536e-01,
#        -6.87515445e-01, -1.99787391e+00, -4.69653211e-01, -1.20266126e-01,
#        -1.83229589e-01, -6.63372684e-01,  1.38157105e+00,  3.07443872e-01,
#        -2.32817308e+00,  1.63547492e+00,  3.55481990e-01, -7.00190769e-01,
#        -6.75940369e-02, -1.55417172e-01,  1.01732338e+00, -1.03984184e-01,
#        -1.08113257e+00,  1.44785189e+00,  3.57631503e-01,  8.64746684e-01,
#        -2.37049529e-01, -1.11380102e+00, -7.37283644e-01, -3.19255599e-01,
#         2.29023930e-01, -4.70727384e-01, -1.50549232e-01, -5.68651135e-01,
#         7.17342786e-01,  2.01967882e-01,  1.25682075e+00,  2.04464759e-01,
# ...

# %% [markdown]
# ### subplotts

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2, ncols = 2, figsize = (10,5))
ax1.plot(x, x/2)
ax1.set(title="11")
ax2.plot(x, np.sin(x))
ax3.bar(nut_price.keys(), nut_price.values())
ax4.hist(np.random.rand(1000));

# %%
# option 2
fig , ax = plt.subplots(nrows = 2, ncols= 2, figsize = (10,5))
ax[0,0].plot(x, x/2)
ax[0,1].plot(x, x**2)
ax[1,0].scatter(x, x/2)
ax[1,1].bar(nut_price.keys(), nut_price.values());

# %% [markdown]
# ### Plotting pandas

# %%
import pandas as pd
car = pd.read_csv("car-sales.csv")

# %%
car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
np.random.seed(1)
t = pd.Series(np.random.randn(1000), index = pd.date_range("1/2/2020", periods = 1000))
t = t.cumsum()
t.plot()
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots()
ax.plot(t)

# %%
car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car["Price"] = car["Price"].str.replace('[\$\,\.]', '', regex = True).astype(int)

# %%
car.Price = car.Price/100

# %%
car
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car["sale date"] = pd.date_range("1/1/2020", periods = len(car))

# %%
car
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  sale date
# 0  Toyota  White         150043      4   4000.0 2020-01-01
# 1   Honda    Red          87899      4   5000.0 2020-01-02
# 2  Toyota   Blue          32549      3   7000.0 2020-01-03
# 3     BMW  Black          11179      5  22000.0 2020-01-04
# 4  Nissan  White         213095      4   3500.0 2020-01-05
# 5  Toyota  Green          99213      4   4500.0 2020-01-06
# 6   Honda   Blue          45698      4   7500.0 2020-01-07
# 7   Honda   Blue          54738      4   7000.0 2020-01-08
# 8  Toyota  White          60000      4   6250.0 2020-01-09
# 9  Nissan  White          31600      4   9700.0 2020-01-10

# %%
car["total"] = car.Price.cumsum()

# %%
car
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  sale date    total
# 0  Toyota  White         150043      4   4000.0 2020-01-01   4000.0
# 1   Honda    Red          87899      4   5000.0 2020-01-02   9000.0
# 2  Toyota   Blue          32549      3   7000.0 2020-01-03  16000.0
# 3     BMW  Black          11179      5  22000.0 2020-01-04  38000.0
# 4  Nissan  White         213095      4   3500.0 2020-01-05  41500.0
# 5  Toyota  Green          99213      4   4500.0 2020-01-06  46000.0
# 6   Honda   Blue          45698      4   7500.0 2020-01-07  53500.0
# 7   Honda   Blue          54738      4   7000.0 2020-01-08  60500.0
# 8  Toyota  White          60000      4   6250.0 2020-01-09  66750.0
# 9  Nissan  White          31600      4   9700.0 2020-01-10  76450.0

# %%
car["total"][len(car)-1]
# Out:
# 76450.0

# %%
car.plot(x = "sale date", y = "total")
# Out:
# <Axes: xlabel='sale date'>

# %%
car.plot(x = "Odometer (KM)", y = "Price", kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
x = np.random.rand(10, 4)
df = pd.DataFrame(x, columns = ['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.386989  0.492881  0.254438  0.884967
# 1  0.383263  0.297575  0.717595  0.190870
# 2  0.118193  0.836998  0.744136  0.590521
# 3  0.242892  0.623247  0.638355  0.327569
# 4  0.067489  0.880539  0.459957  0.763873
# 5  0.253889  0.591387  0.428795  0.382101
# 6  0.126713  0.244267  0.079342  0.302858
# 7  0.741705  0.615016  0.672411  0.008383
# 8  0.678377  0.503181  0.230908  0.174897
# 9  0.184983  0.844260  0.982590  0.913740

# %%
df.plot( kind = 'bar')
# Out:
# <Axes: >

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
car
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  sale date    total
# 0  Toyota  White         150043      4   4000.0 2020-01-01   4000.0
# 1   Honda    Red          87899      4   5000.0 2020-01-02   9000.0
# 2  Toyota   Blue          32549      3   7000.0 2020-01-03  16000.0
# 3     BMW  Black          11179      5  22000.0 2020-01-04  38000.0
# 4  Nissan  White         213095      4   3500.0 2020-01-05  41500.0
# 5  Toyota  Green          99213      4   4500.0 2020-01-06  46000.0
# 6   Honda   Blue          45698      4   7500.0 2020-01-07  53500.0
# 7   Honda   Blue          54738      4   7000.0 2020-01-08  60500.0
# 8  Toyota  White          60000      4   6250.0 2020-01-09  66750.0
# 9  Nissan  White          31600      4   9700.0 2020-01-10  76450.0

# %%
car.plot(x = "Make", y = "Odometer (KM)", kind = 'bar');

# %%
car["Odometer (KM)"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
car["Odometer (KM)"].plot.hist(bins = 5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
heart = pd.read_csv("heart-disease.csv")
heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart["age"].plot.hist(bins = 50);

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart.plot.hist(figsize = (10,30), subplots = True);

# %%
#whichone to use? pyplot or matplotlub
# plotting quick thing - pyplot, in other matplotlib
heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
over_50 = heart[heart["age"]>50]

# %%
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
#pyplot
over_50.plot(kind = "scatter", x ="age", y = "chol", c = "target")
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
#mixed OO with pyplot
fig, ax = plt.subplots(figsize = (10,6))
over_50.plot(kind = "scatter", x = "age", y ="chol", c = "target", ax= ax)
ax.set_xlim([45,100])
ax.set_ylim([100, 400])
# Out:
# (100.0, 400.0)

# %%
fix, ax = plt.subplots(nrows = 2, ncols = 1, figsize = (10, 6))
scatter = ax[0].scatter(x = over_50["age"],
                    y = over_50["chol"],
                    c = over_50["target"]);
#customiz
ax[0].set(title = "heart disease and cholestorel", 
      xlabel="Age",
      ylabel="Cholesterol");
ax[0].legend(*scatter.legend_elements(), title = "Target")
ax[0].axhline(over_50["chol"].mean(),
          linestyle = '--', color = 'black');
scatter_2 = ax[1].scatter(x = over_50["age"],y = over_50["thalach"], c = over_50["sex"])
ax[1].legend(*scatter.legend_elements(), title = "Sex")

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 1, figsize = (10,10), sharex = True)
scatter = ax[0].scatter(x = over_50["age"], y = over_50["chol"], c = over_50["target"])
ax[0].set(title = "heart disease", ylabel = "chol")
ax[0].legend(*scatter.legend_elements(), title = "target")
ax[0].axhline(over_50["chol"].mean(), linestyle = '--')
scatter1 = ax[1].scatter(x = over_50["age"], y = over_50["thalach"], c = over_50["target"])
ax[1].set(title = "Heart disease and max heart rate", xlabel= "age", ylabel = "Max Heart rate")
ax[1].legend(*scatter1.legend_elements(), title = "target")
ax[1].axhline(over_50["thalach"].mean(), linestyle = "-.");
fig.suptitle("Heart dis analysis", fontsize = 16, fontweight = "bold")
# Out:
# Text(0.5, 0.98, 'Heart dis analysis')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car = pd.read_csv("car-sales.csv")
car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
plt.style.use('seaborn')
car["Odometer (KM)"].plot();
# Out:
# /var/folders/72/s5183t1j2l35dqr7bg28v01h0000gn/T/ipykernel_17801/1477777411.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
plt.style.use('ggplot')
car["Odometer (KM)"].plot();

# %%
# plt.style.use('seaborn')

fig, ax = plt.subplots(nrows = 2, ncols = 1, figsize = (10,10), sharex = True)
scatter = ax[0].scatter(x = over_50["age"], y = over_50["chol"], c = over_50["target"], cmap = "winter")

ax[0].set(title = "heart disease", ylabel = "chol")
ax[0].legend(*scatter.legend_elements(), title = "target")
ax[0].axhline(over_50["chol"].mean(), linestyle = '--')
ax[0].set_xlim([50,80])

scatter1 = ax[1].scatter(x = over_50["age"], y = over_50["thalach"], c = over_50["target"],  cmap = "winter")
ax[1].set(title = "Heart disease and max heart rate", xlabel= "age", ylabel = "Max Heart rate")
ax[1].legend(*scatter1.legend_elements(), title = "target")
ax[1].set_xlim([50,80])
ax[1].set_ylim([60,200])

ax[1].axhline(over_50["thalach"].mean(), linestyle = "-.");

fig.suptitle("Heart dis analysis", fontsize = 16, fontweight = "bold")
# Out:
# Text(0.5, 0.98, 'Heart dis analysis')

# %%
fig.savefig("Heart-disease.png")
